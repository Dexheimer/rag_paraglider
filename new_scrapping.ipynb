# %% [markdown]
# <a href="https://colab.research.google.com/github/Dexheimer/rag_paraglider/blob/Dexheimer-patch-1/new_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [1] Dataset: Webscraping paragliding sites**
#
# - I'll use other method to scrape https://guia4ventos.com.br

# %%
pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders.recursive_url_loader import RecursiveUrlLoader

# %%
from bs4 import BeautifulSoup as Soup

url = "https://guia4ventos.com.br"
loader = RecursiveUrlLoader(
    url=url, max_depth=2, extractor=lambda x: Soup(x, "html.parser").text
)
docs = loader.load()
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
print(docs)
# Out:
# [Document(page_content="     Guia4Ventos » Rampas de voo livre asa-delta, parapente        \nRampas de voo livreRampas do SudesteMinas Gerais – MGRio de Janeiro – RJSão Paulo – SPEspírito Santo – ESRampas do SulParaná – PRRio Grande do Sul – RSSanta Catarina – SCRampas do NordesteAlagoas – ALBahia – BACeará – CEMaranhão – MAParaíba – PBPernambuco – PERio Grande do Norte – RNSergipe – SERampas do Centro-OesteGoiás – GOMato Grosso – MTMato Grosso do Sul – MSRampas do NorteRondônia – RORoraima – RRTocantins – TOLojaArtigos e colunasMeteorologiaContatoAnuncieCadastro\n \nPesquisar por:\n\n\n\nGuia 4 Ventos – Rampas de Voo Livre de Asa delta e ParapenteO maior site de rampas de voo livre no Brasil, com informações sobre os principais pontos para a prática de Parapente e Asa-delta.Campo Largo – Morro do Cal – PRAltitude: 1.050m Desnível: 200m Quadrante: \xa0Norte (N), Nordeste (NE), Sudeste (SE), Sul (S), Sudoeste (SW), Oeste(W), Noroeste (NW) Local:\xa0Campo Largo - Morro do Cal - PR WayP
# ...

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
# !pip install openai

YOUR_API_KEY

from langchain.embeddings import OpenAIEmbeddings

# %%
YOUR_API_KEY =
embeddings = OpenAIEmbeddings()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-30-ad82f24a8d1f> in <cell line: 2>()
#       1 YOUR_API_KEY = "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"
# ----> 2 embeddings = OpenAIEmbeddings()
#
# /usr/local/lib/python3.10/dist-packages/pydantic/main.cpython-310-x86_64-linux-gnu.so in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter. (type=value_error)

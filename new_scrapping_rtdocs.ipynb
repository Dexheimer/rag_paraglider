# %%
# !wget -r -A.html -P rtdocs https://guia4ventos.com.br/

# %%
# !pip install langchain

from langchain.document_loaders import ReadTheDocsLoader

# %%
loader = ReadTheDocsLoader("rtdocs")
docs = loader.load()
print(len(docs))
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# 1378

# %%
print(docs[789
           ])
# Out:
# page_content='' metadata={'source': 'rtdocs/guia4ventos.com.br/porto-uniao-morro-do-carvao-sc/feed/index.html'}

# %%
print(docs[789].metadata["source"].replace("rtdocs/", "https://"))
# Out:
# https://guia4ventos.com.br/porto-uniao-morro-do-carvao-sc/feed/index.html

# %%
# !pip install tiktoken
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

# create the lenght function

def tiktoken_len(text):
    tokens = tokenizer.encode(text, disallowed_special=())
    return len(tokens)

# %%
token_counts = [tiktoken_len(doc.page_content) for doc in docs]

# %%
print(f"Min: {min(token_counts)}, Avg: {int(sum(token_counts) / len(token_counts))}, Max: {max(token_counts)}")
# Out:
# Min: 0, Avg: 0, Max: 0
